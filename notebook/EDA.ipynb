# %% [markdown]
# ### Importing Librares

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Reading The Data

# %%
df = pd.read_csv( '../data/raw/spotify-tracks-dataset.csv' )

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                  0           0  5SuOikwiRyPMVoIQDJUgSV
# 1                  1           1  4qPNDBW1i3p13qLCt0Ki3A
# 2                  2           2  1iJBSr7s7jYXzM8EGcbK5b
# 3                  3           3  6lfxq3CG4xtTiEg7opyCyx
# 4                  4           4  5vjLSffimiIP26QG5WcN2K
# ...              ...         ...                     ...
# 113995        113995      113995  2C3TZjDRiAzdyViavDJ217
# 113996        113996      113996  1hIz5L4IB9hN3WRYPOCGPw
# 113997        113997      113997  6x8ZfSoqDjuNa5SVP5QjvX
# 113998        113998      113998  2e6sXL2bYv4bSz6VTdnfLs
# 113999        113999      113999  2hETkH7cOfqmz3LqZDHZf5
#
#                        artists  \
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'track_id', 'artists', 'album_name',
#        'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0.1','Unnamed: 0'],inplace=True)

# %%
df
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
df['track_id'].isna().sum()
# Out:
# np.int64(0)

# %%
df['artists'].isna().sum()
# Out:
# np.int64(1)

# %%
df[df['artists'].isna()].index
# Out:
# Index([65900], dtype='int64')

# %%
df.drop(65900,inplace=True)

# %%
df['artists'].isna().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
df['album_name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['track_name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['popularity'].isna().sum()
# Out:
# np.int64(0)

# %%
df['duration_ms'].isna().sum()
# Out:
# np.int64(0)

# %%
df['duration_ms'].dtype
# Out:
# dtype('int64')

# %%
df['duration_ms'].shape
# Out:
# (113999,)

# %%
duration_min =[]
for time in df['duration_ms'] :
    duration_min.append(time/60000)
len(duration_min)
# Out:
# 113999

# %%
df.insert(6,'Duration_Min',duration_min)

# %%
df
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'Duration_Min', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df['explicit'].isna().sum()
# Out:
# np.int64(0)

# %%
df['danceability'].dtype
# Out:
# dtype('float64')

# %%
df['energy'].isna().sum()
# Out:
# np.int64(0)

# %%
px.box(df,'danceability')

# %%
df['key'].isna().sum()
# Out:
# np.int64(0)

# %%
df['loudness'].isna().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'Duration_Min', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df['mode'].isna().sum()
# Out:
# np.int64(0)

# %%
df['speechiness'].dtype
# Out:
# dtype('float64')

# %%
df['acousticness'].unique()
# Out:
# array([3.22e-02, 9.24e-01, 2.10e-01, ..., 7.87e-05, 6.64e-06, 9.28e-06],
#       shape=(5061,))

# %%
df['instrumentalness'].isna().sum()
# Out:
# np.int64(0)

# %%
df['liveness'].isna().sum()
# Out:
# np.int64(0)

# %%
df['valence'].isna().sum()
# Out:
# np.int64(0)

# %%
df['tempo'].isna().sum()
# Out:
# np.int64(0)

# %%
df['time_signature'].unique()
# Out:
# array([4, 3, 1, 5, 0])

# %%
df['track_genre'].isna().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df['artists'].nunique()
# Out:
# 31437

# %%
df.shape
# Out:
# (113999, 21)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (113549, 21)

# %%
df['track_name'].value_counts()
# Out:
# track_name
# Run Rudolph Run                      151
# Halloween                             88
# Frosty The Snowman                    80
# Little Saint Nick - 1991 Remix        74
# Christmas Time                        72
#                                     ...
# Ambient Attention, Pt. 14              1
# My Heart Is Yours - Radio Version      1
# Promises Never Fail - Live             1
# How Great Is Our God - Live            1
# Forever Be Praised                     1
# Name: count, Length: 73608, dtype: int64

# %%
df[df['track_name']=='Run Rudolph Run']
# Out:
#                      track_id      artists  \
# 8163   1S4rxDloMtAduogKeiJZmR  Chuck Berry
# 8164   03MW3H9B2P7tgpvzG3klNI  Chuck Berry
# 8165   52MCmoSCtPRbVN5Njdo6G5  Chuck Berry
# 8166   7m4luTtlene5vS6xUvWxRt  Chuck Berry
# 8168   3RXAcz7Sa6JDZSxcH1EEQ6  Chuck Berry
# ...                       ...          ...
# 92043  3iyTXUFlm1YrquUUgXlPM1  Chuck Berry
# 92044  0XgmLT6nDInA6w2yxpVsZh  Chuck Berry
# 92046  4vJrtcgQoULwkPyFkXNYCx  Chuck Berry
# 92049  3IUpuyEMIgt4GvEZ2TqERF  Chuck Berry
# 92818  2pnPe4pJtq7689i5ydzvJJ  Chuck Berry
#
#                                               album_name       track_name  \
# 8163                             CHRISTMAS TOP HITS 2022  Run Rudolph Run
# 8164                      pov: you hear the bells jingle  Run Rudolph Run
# 8165                                Weihnachten Playlist  Run Rudolph Run
# 8166                                 Holidays Are Coming  Run Rudolph Run
# ...
